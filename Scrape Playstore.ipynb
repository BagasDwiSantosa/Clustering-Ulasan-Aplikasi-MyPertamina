# %%
# !pip install google_play_scraper
# !pip install app_store_scraper
# Out:
# Requirement already satisfied: google_play_scraper in /usr/local/lib/python3.10/dist-packages (1.2.4)
# Requirement already satisfied: app_store_scraper in /usr/local/lib/python3.10/dist-packages (0.3.5)
# Requirement already satisfied: requests==2.23.0 in /usr/local/lib/python3.10/dist-packages (from app_store_scraper) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from requests==2.23.0->app_store_scraper) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests==2.23.0->app_store_scraper) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests==2.23.0->app_store_scraper) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests==2.23.0->app_store_scraper) (2023.7.22)

# %%
from google_play_scraper import app, Sort, reviews_all
from app_store_scraper import AppStore
import pandas as pd
import numpy as np
import json, os, uuid

# %%
scrapreview= reviews_all(
    "com.dafturn.mypertamina", #ID aplikasi
    lang="id", # defaults to ‘en’
    country="id", # defaults to ‘us’
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    filter_score_with=None # defaults to None (means all score)
)

# %%
print(scrapreview)
app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.to_csv('scrape_mypertamina_playstore.csv', index=None, header=True)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
app_reviews_df
# Out:
#                                    reviewId            userName  \
# 0      d7393145-8a62-4946-b1f9-8733899fa76f    Angga Ferdianova
# 1      ece29b3b-1f85-40dc-9252-9d80f0776c7c       Hendro Wibowo
# 2      089a2947-0674-45ba-ab88-79b45f5ebd43          Gustan Lie
# 3      89250100-9ed1-486a-b069-4ebc8c1ac110  Restu Hidayatullah
# 4      db8528e2-7ca7-406a-9b73-6f698494894b       Ruben Nugroho
# ...                                     ...                 ...
# 87754  c4055d9e-1182-4a9e-8fc6-e155901a1777     Heri Hendrayana
# 87755  ef5cc787-7724-45fe-b250-0aa59e9ea0ad       Regi Setiawan
# 87756  ae8fd45b-fe02-49f2-a702-0ebac42454d7       Herwi Haryono
# 87757  0e76d867-a876-4863-990c-bd4a43a3b069       Agung Cahyono
# 87758  ef6cf35e-489a-4d62-8cd7-e817538d2a80             fatroji
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a-/ALV-U...
# 1      https://play-lh.googleusercontent.com/a-/ALV-U...
# 2      https://play-lh.googleusercontent.com/a-/ALV-U...
# 3      https://play-lh.googleusercontent.com/a-/ALV-U...
# 4      https://play-lh.googleusercontent.com/a-/ALV-U...
# ...                                                  ...
# 87754  https://play-lh.googleusercontent.com/a/ACg8oc...
# 87755  https://play-lh.googleusercontent.com/a-/ALV-U...
# 87756  https://play-lh.googleusercontent.com/a-/ALV-U...
# 87757  https://play-lh.googleusercontent.com/a-/ALV-U...
# 87758  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                                  content  score  \
# 0      Saat pendaftaran selalu di tolak dengan alasan...      1
# 1      Khusus wilayah JaTeng ada penomoran ulang kend...      1
# 2      Untuk aplikasinya bagus, bisa kontrol dan anal...      5
# 3      Buat apa ada aplikasi kalau spbu nya tidak men...      2
# 4      Sangat kecewa, mau membeli BBM harus pakai apl...      1
# ...                                                  ...    ...
# 87754                                              Payah      1
# 87755                                              Ribet      1
# 87756                                              Ribet      1
# 87757                                            Nyusain      1
# 87758                                              Baned      1
#
#        thumbsUpCount reviewCreatedVersion                  at replyContent  \
# 0                100                4.0.2 2023-08-30 00:34:55         None
# 1                 81                4.0.2 2023-09-01 11:54:33         None
# 2                 82                4.0.2 2023-08-22 02:07:19         None
# 3                 47                4.0.2 2023-08-24 02:22:04         None
# 4                 33                4.0.2 2023-08-27 10:02:56         None
# ...              ...                  ...                 ...          ...
# 87754              0                3.6.0 2022-06-29 11:17:27         None
# 87755              0                3.6.0 2022-07-02 07:20:52         None
# 87756              0                3.6.0 2022-06-29 10:39:15         None
# 87757              0                3.6.0 2022-06-30 11:05:10         None
# 87758              0                3.6.0 2022-06-30 05:04:16         None
#
#       repliedAt appVersion
# 0           NaT      4.0.2
# 1           NaT      4.0.2
# 2           NaT      4.0.2
# 3           NaT      4.0.2
# 4           NaT      4.0.2
# ...         ...        ...
# 87754       NaT      3.6.0
# 87755       NaT      3.6.0
# 87756       NaT      3.6.0
# 87757       NaT      3.6.0
# 87758       NaT      3.6.0
#
# [87759 rows x 11 columns]
